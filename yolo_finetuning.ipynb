# %%
# !pip install ultralytics

# %%
import ultralytics
import os
import shutil
from tqdm.notebook import tqdm

# %%
train_img_path='./yolo_data/images/train/'
train_label_path='./yolo_data/labels/train/'
val_img_path='./yolo_data/images/val/'
val_label_path='./yolo_data/labels/val/'

# %%
import random
random.seed(42)

# %%
def train_test_split(path,split=0.2):
  files=list(name[:-4] for name in os.listdir(path))
  print(files)
  print(len(files))
  test_size=int(len(files)*split)
  train_size=len(files)-test_size
  random.shuffle(files)

  os.makedirs(train_img_path,exist_ok=True)
  os.makedirs(train_label_path,exist_ok=True)
  os.makedirs(val_img_path,exist_ok=True)
  os.makedirs(val_label_path,exist_ok=True)

  for file in tqdm(files[:train_size]):
    shutil.copy2(path+file+'.jpg',train_img_path)
    shutil.copy2(path+file+'.txt',train_label_path)

  for file in tqdm(files[train_size:]):
    shutil.copy2(path+file+'.jpg',val_img_path)
    shutil.copy2(path+file+'.txt',val_label_path)

# %%
train_test_split('/content/drive/MyDrive/custom_yolo_finetune/data/')
# Out:
# ['fre_f_145_6ty', 'fre_f_190_22d', 'we_f_105', 'fre_f_190_22d', 'we_f_30', 'fre_f_60_fr', 'we_f_100', 'rt3_f_170_6ty', 'we_f_20', 'fre_f_45_22d', 'we_f_150_we', 'we_f_150_we', 'rt3_f_110', 'we_f_20', 'fre_f_35', 'we_f_175_we', 'rt3_f_35_rt3', 'fre_f_95_54r', 'fre_f_115', 'we_f_100', 'fre_f_40_22d', 'we_f_175_we', 'we_f_30', 'fre_f_115', 'rt3_f_95', 'rt3_f_20_54r', 'fre_f_60_fr', 'we_f_115_fre', 'we_f_50', 'we_f_115_fre', 'we_f_50', 'rt3_f_110', 'fre_f_70_rt3', 'fre_f_155_we', 'we_f_105', 'fre_f_5', '6ty_f_195_6ty', 'fr_f_105_6ty', 'fre_f_145_6ty', 'fre_f_95_54r', 'fr_f_10', 'rt3_f_25_6ty', 'fre_f_60', '6ty_f_90_we', 'fre_f_10_54r', 'rt3_f_20_54r', 'fre_f_60', 'fre_f_45_22d', '6ty_f_130_22d', 'fre_f_70_rt3', '6ty_f_65_we', 'fr_f_45', 'fr_f_100_we', 'rt3_f_35_rt3', '6ty_f_50_we', 'fr_f_10', 'fre_f_40_22d', 'fr_f_140_fre', 'fre_f_10_54r', '6ty_f_90_we', 'fr_f_160_fre', 'fr_f_160_fre', 'rt3_f_25_6ty', 'rt3_f_95', '6ty_f_85', 'fre_f_155_we', '6ty_f_85', 'fre_f_5', 'rt3_f_170_6ty', 'fr_f_1
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='/content/drive/MyDrive/custom_yolo_finetune/dataset.yaml' epochs=10 batch=8 project='/content/drive/MyDrive/custom_yolo_finetune/training_results' name=football
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/custom_yolo_finetune/training_results/football/weights/best.pt' conf=0.5 source=/content/drive/MyDrive/custom_yolo_finetune/test_images
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/6 /content/drive/MyDrive/custom_yolo_finetune/test_images/test_img1.jpg: 384x640 12 players, 1 football, 76.4ms
# image 2/6 /content/drive/MyDrive/custom_yolo_finetune/test_images/test_img2.jpg: 384x640 13 players, 1 football, 10.7ms
# image 3/6 /content/drive/MyDrive/custom_yolo_finetune/test_images/test_img3.jpg: 384x640 12 players, 1 football, 10.6ms
# image 4/6 /content/drive/MyDrive/custom_yolo_finetune/test_images/test_img4.jpg: 384x640 12 players, 10.6ms
# image 5/6 /content/drive/MyDrive/custom_yolo_finetune/test_images/test_img5.jpg: 384x640 12 players, 1 football, 10.6ms
# image 6/6 /content/drive/MyDrive/custom_yolo_finetune/test_images/test_img6.jpg: 384x640 6 players, 10.7ms
# Speed: 2.7ms preprocess, 21.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/custom_yolo_finetune/training_results/football/weights/best.pt' conf=0.5 source=/content/drive/MyDrive/custom_yolo_finetune/vid2
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/2 (frame 1/352) /content/drive/MyDrive/custom_yolo_finetune/vid2/test_video1.mp4: 384x640 5 players, 56.7ms
# video 1/2 (frame 2/352) /content/drive/MyDrive/custom_yolo_finetune/vid2/test_video1.mp4: 384x640 5 players, 10.9ms
# video 1/2 (frame 3/352) /content/drive/MyDrive/custom_yolo_finetune/vid2/test_video1.mp4: 384x640 5 players, 10.7ms
# video 1/2 (frame 4/352) /content/drive/MyDrive/custom_yolo_finetune/vid2/test_video1.mp4: 384x640 5 players, 10.7ms
# video 1/2 (frame 5/352) /content/drive/MyDrive/custom_yolo_finetune/vid2/test_video1.mp4: 384x640 5 players, 10.7ms
# video 1/2 (frame 6/352) /content/drive/MyDrive/custom_yolo_finetune/vid2/test_video1.mp4: 384x640 6 players, 10.9ms
# video 1/2 (frame 7/352) /content/drive/MyDrive/custom_yolo_finetune/vid2/test_video1.mp4: 384x640 5 players, 10.9ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/custom_yolo_finetune/image_output

# %%
# !cp -r /content/runs/detect/predict-2 /content/drive/MyDrive/custom_yolo_finetune/image_output
